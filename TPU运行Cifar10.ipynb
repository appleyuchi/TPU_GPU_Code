# %%
#代码来自：
#https://blog.shikoan.com/colab-tpu-resnet-benchmarks/
# !pip install tensorflow==1.13.1
# Out:
# Requirement already satisfied: tensorflow==1.13.1 in /usr/local/lib/python3.6/dist-packages (1.13.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (0.2.2)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.13.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.16.5)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.12.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (0.33.6)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.13.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (0.8.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.0.8)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (3.7.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1) (0.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (0.15.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.1.1)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow==1.13.1) (3.0.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow==1.13.1) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.13.1) (41.2.0)

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization, Add, Input, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import Callback, LearningRateScheduler
from tensorflow.keras.optimizers import SGD
from keras.regularizers import l2
from tensorflow.contrib.tpu.python.tpu import keras_support
import time, pickle, os

# 経過時間用のコールバック
class TimeHistory(Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch_start_time = time.time()

    def on_epoch_end(self, epoch, logs={}):
        self.times.append(time.time() - self.epoch_start_time)

class ResNet:
    def __init__(self, n, framework, initial_lr=0.01, nb_epochs=100):
        self.n = n
        # バッチサイズがかなり違うので学習率は要調整
        self.framework = framework
        self.initial_lr = initial_lr
        self.nb_epochs = nb_epochs
        self.weight_decay = 0.0005
        # Make model
        self.model = self.make_model()

    # オリジナルの論文に従って、サブサンプリングにPoolingではなくstride=2のConvを使う
    def subsumpling(self, output_channels, input_tensor):
        return Conv2D(output_channels, kernel_size=1, strides=(2,2), kernel_regularizer=l2(self.weight_decay))(input_tensor)

    # BN->ReLU->Conv->BN->ReLU->Conv をショートカットさせる(Kaimingらの研究による)
    # https://www.slideshare.net/KotaNagasato/resnet-82940994
    def block(self, channles, input_tensor):
        # ショートカット元
        shortcut = input_tensor
        # メイン側
        x = BatchNormalization()(input_tensor)
        x = Activation("relu")(x)
        x = Conv2D(channles, kernel_size=3, padding="same", kernel_regularizer=l2(self.weight_decay))(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        x = Conv2D(channles, kernel_size=3, padding="same", kernel_regularizer=l2(self.weight_decay))(x)
        # 結合
        return Add()([x, shortcut])

    def make_model(self):
        input = Input(shape=(32, 32, 3))
        # 3->16にチャンネル数を増やす
        x = Conv2D(16, kernel_size=3, padding="same", kernel_regularizer=l2(self.weight_decay))(input)
        # 32x32x16のブロックをn回
        for i in range(self.n):
            x = self.block(16, x)
        # 16x16x32
        x = self.subsumpling(32, x)
        for i in range(self.n):
            x = self.block(32, x)
        # 8x8x64
        x = self.subsumpling(64, x)
        for i in range(self.n):
            x = self.block(64, x)
        # Global Average Pooling
        x = GlobalAveragePooling2D()(x)
        x = Dense(10, activation="softmax")(x)
        # model
        model = Model(input, x)
        return model

    def lr_schduler(self, epoch):
        x = self.initial_lr
        if epoch >= self.nb_epochs * 0.5: x /= 10.0
        if epoch >= self.nb_epochs * 0.75: x /= 10.0
        return x

    def train(self, X_train, y_train, X_val, y_val):
        # コンパイル
        self.model.compile(optimizer=SGD(lr=self.initial_lr, momentum=0.9),
                          loss="categorical_crossentropy", metrics=["acc"])
        # Data Augmentation
        traingen = ImageDataGenerator(
            rescale=1./255,
            width_shift_range=4./32,
            height_shift_range=4./32,
            horizontal_flip=True)
        valgen = ImageDataGenerator(
            rescale=1./255)
        # TPU
        tpu_grpc_url = "grpc://"+os.environ["COLAB_TPU_ADDR"]
        tpu_cluster_resolver = tf.contrib.cluster_resolver.TPUClusterResolver(tpu_grpc_url)
        strategy = keras_support.TPUDistributionStrategy(tpu_cluster_resolver)
        self.model = tf.contrib.tpu.keras_to_tpu_model(self.model, strategy=strategy)

        # Callback
        time_cb = TimeHistory()
        lr_cb = LearningRateScheduler(self.lr_schduler)
        # Train
        history = self.model.fit_generator(traingen.flow(X_train, y_train, batch_size=1024), epochs=self.nb_epochs,
                                           steps_per_epoch=len(X_train)/1024, validation_data=valgen.flow(X_val, y_val, batch_size=1024),
                                           validation_steps=len(X_val)/1024,
                                           callbacks=[time_cb, lr_cb]).history
        history["time"] = time_cb.times
        # Save history
        file_name = f"{self.framework}_n{self.n}.dat"
        with open(file_name, "wb") as fp:
            pickle.dump(history, fp)

# Main function
def main(n, framework):
    K.clear_session()
    # layers = 6n+2
    net = ResNet(n, framework, nb_epochs=100)
    # CIFAR
    (X_train, y_train), (X_test, y_test) = cifar10.load_data()
    y_train, y_test = to_categorical(y_train), to_categorical(y_test)
    # train
    net.train(X_train, y_train, X_test, y_test)

if __name__ == "__main__":
    main(3, "tf_keras_tpu")
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Querying Tensorflow master (grpc://10.94.17.170:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 5318427542844900690)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 5972651299852305070)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 16868474098292505710)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 7432862407376987853)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 8452046943043630676)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 4894794154746251569)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 16242358405714188922)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 15231011154896667063)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 1938731572797274520)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 9964760283833988398)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 7014322032663729690)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Cloning SGD {'lr': 0.009999999776482582, 'momentum': 0.8999999761581421, 'decay': 0.0, 'nesterov': False}
# INFO:tensorflow:Cloning SGD {'lr': 0.009999999776482582, 'momentum': 0.8999999761581421, 'decay': 0.0, 'nesterov': False}
# Epoch 1/100
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(128,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(128, 32, 32, 3), dtype=tf.float32, name='input_1_10'), TensorSpec(shape=(128, 10), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning SGD {'lr': 0.009999999776482582, 'momentum': 0.8999999761581421, 'decay': 0.0, 'nesterov': False}
# INFO:tensorflow:Remapping placeholder for input_1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/tpu/python/tpu/keras_support.py:302: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.SGD object at 0x7f8e2b748550> []
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 11.385817527770996 secs
# INFO:tensorflow:Setting weights on TPU model.
# INFO:tensorflow:CPU -> TPU lr: 0.009999999776482582 {0.01}
# INFO:tensorflow:CPU -> TPU momentum: 0.8999999761581421 {0.9}
# INFO:tensorflow:CPU -> TPU decay: 0.0 {0.0}
# WARNING:tensorflow:Cannot update non-variable config: nesterov
# 21/49 [===========>..................] - ETA: 1:05 - loss: 2.5399 - acc: 0.2125INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(106,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(106, 32, 32, 3), dtype=tf.float32, name='input_1_10'), TensorSpec(shape=(106, 10), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for input_1
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.SGD object at 0x7f8e2b748550> [<tf.Variable 'tpu_140248638363800/SGD/iterations:0' shape=() dtype=int64>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e265c1be0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e265c1eb8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e265e1630>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e2658b668>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e264fccf8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e26491550>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e26491e48>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e26432c18>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e26403da0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e26372940>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e2633f4e0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e2630c780>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e262afd30>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e262476a0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e2620f1d0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e2626beb8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e26180cf8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e26118828>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e260be710>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e260e1c88>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e26088e48>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e2601dc18>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25f31d68>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25f556a0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25f238d0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25e3b208>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25e3bb00>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25e06160>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25dce518>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25d41da0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25d64e80>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25c79dd8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25c9e978>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25c43e48>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25c11f28>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25ba68d0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f8e25b16ba8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f ...
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 12.1472327709198 secs
# 48/49 [============================>.] - ETA: 1s - loss: 2.3087 - acc: 0.2831INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(128,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(128, 32, 32, 3), dtype=tf.float32, name='input_1_10'), TensorSpec(shape=(128, 10), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning SGD {'lr': 0.009999999776482582, 'momentum': 0.8999999761581421, 'decay': 0.0, 'nesterov': False}
# INFO:tensorflow:Remapping placeholder for input_1
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.SGD object at 0x7f8e1c2441d0> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 8.65952754020691 secs
#  9/10 [==========================>...] - ETA: 1s - loss: 2.6732 - acc: 0.1459INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(98,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(98, 32, 32, 3), dtype=tf.float32, name='input_1_10'), TensorSpec(shape=(98, 10), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for input_1
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.SGD object at 0x7f8e1c2441d0> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 5.899410247802734 secs
# 10/10 [==============================] - 23s 2s/step - loss: 2.6726 - acc: 0.1459
# 49/49 [==============================] - 108s 2s/step - loss: 2.3035 - acc: 0.2845 - val_loss: 2.6726 - val_acc: 0.1459
# Epoch 2/100
# 10/10 [==============================] - 1s 133ms/step - loss: 2.8799 - acc: 0.1693
# 49/49 [==============================] - 17s 337ms/step - loss: 1.9664 - acc: 0.4042 - val_loss: 2.8799 - val_acc: 0.1693
# Epoch 3/100
# 10/10 [==============================] - 1s 132ms/step - loss: 3.0991 - acc: 0.1638
# 49/49 [==============================] - 20s 407ms/step - loss: 1.8401 - acc: 0.4598 - val_loss: 3.0991 - val_acc: 0.1638
# Epoch 4/100
# 10/10 [==============================] - 1s 124ms/step - loss: 2.8439 - acc: 0.2025
# 49/49 [==============================] - 20s 402ms/step - loss: 1.7443 - acc: 0.4951 - val_loss: 2.8439 - val_acc: 0.2025
# Epoch 5/100
# 10/10 [==============================] - 1s 131ms/step - loss: 3.1338 - acc: 0.1962
# 49/49 [==============================] - 20s 408ms/step - loss: 1.6749 - acc: 0.5223 - val_loss: 3.1338 - val_acc: 0.1962
# Epoch 6/100
# 10/10 [==============================] - 1s 127ms/step - loss: 2.6096 - acc: 0.2802
# 49/49 [==============================] - 20s 403ms/step - loss: 1.6104 - acc: 0.5474 - val_loss: 2.6096 - val_acc: 0.2802
# Epoch 7/100
# 10/10 [==============================] - 1s 129ms/step - loss: 1.8398 - acc: 0.4465
# 49/49 [==============================] - 20s 406ms/step - loss: 1.5409 - acc: 0.5715 - val_loss: 1.8398 - val_acc: 0.4465
# Epoch 8/100
# 10/10 [==============================] - 1s 132ms/step - loss: 1.7142 - acc: 0.4913
# 49/49 [==============================] - 20s 405ms/step - loss: 1.4927 - acc: 0.5890 - val_loss: 1.7142 - val_acc: 0.4913
# Epoch 9/100
# 10/10 [==============================] - 1s 129ms/step - loss: 1.6611 - acc: 0.5267
# 49/49 [==============================] - 20s 404ms/step - loss: 1.4430 - acc: 0.6066 - val_loss: 1.6611 - val_acc: 0.5267
# Epoch 10/100
# 10/10 [==============================] - 1s 131ms/step - loss: 1.5727 - acc: 0.5596
# 49/49 [==============================] - 20s 403ms/step - loss: 1.3989 - acc: 0.6202 - val_loss: 1.5727 - val_acc: 0.5596
# Epoch 11/100
# 10/10 [==============================] - 1s 133ms/step - loss: 1.4498 - acc: 0.6066
# 49/49 [==============================] - 20s 407ms/step - loss: 1.3583 - acc: 0.6347 - val_loss: 1.4498 - val_acc: 0.6066
# Epoch 12/100
# 10/10 [==============================] - 1s 136ms/step - loss: 1.5785 - acc: 0.5598
# 49/49 [==============================] - 20s 406ms/step - loss: 1.3157 - acc: 0.6483 - val_loss: 1.5785 - val_acc: 0.5598
# Epoch 13/100
# 10/10 [==============================] - 1s 134ms/step - loss: 1.3907 - acc: 0.6330
# 49/49 [==============================] - 20s 408ms/step - loss: 1.2840 - acc: 0.6607 - val_loss: 1.3907 - val_acc: 0.6330
# Epoch 14/100
# 10/10 [==============================] - 1s 129ms/step - loss: 1.4163 - acc: 0.6184
# 49/49 [==============================] - 20s 404ms/step - loss: 1.2530 - acc: 0.6725 - val_loss: 1.4163 - val_acc: 0.6184
# Epoch 15/100
# 10/10 [==============================] - 1s 124ms/step - loss: 1.3498 - acc: 0.6367
# 49/49 [==============================] - 20s 401ms/step - loss: 1.2241 - acc: 0.6820 - val_loss: 1.3498 - val_acc: 0.6367
# Epoch 16/100
# 10/10 [==============================] - 1s 125ms/step - loss: 2.3644 - acc: 0.4371
# 49/49 [==============================] - 20s 409ms/step - loss: 1.1885 - acc: 0.6934 - val_loss: 2.3644 - val_acc: 0.4371
# Epoch 17/100
# 10/10 [==============================] - 1s 129ms/step - loss: 1.2765 - acc: 0.6628
# 49/49 [==============================] - 20s 410ms/step - loss: 1.1605 - acc: 0.7048 - val_loss: 1.2765 - val_acc: 0.6628
# Epoch 18/100
# 10/10 [==============================] - 1s 140ms/step - loss: 1.6145 - acc: 0.6053
# 49/49 [==============================] - 20s 404ms/step - loss: 1.1338 - acc: 0.7154 - val_loss: 1.6145 - val_acc: 0.6053
# Epoch 19/100
# 10/10 [==============================] - 1s 136ms/step - loss: 1.3215 - acc: 0.6441
# 49/49 [==============================] - 20s 408ms/step - loss: 1.1139 - acc: 0.7182 - val_loss: 1.3215 - val_acc: 0.6441
# Epoch 20/100
# 10/10 [==============================] - 1s 134ms/step - loss: 1.4224 - acc: 0.6276
# 49/49 [==============================] - 20s 410ms/step - loss: 1.0826 - acc: 0.7305 - val_loss: 1.4224 - val_acc: 0.6276
# Epoch 21/100
# 10/10 [==============================] - 1s 132ms/step - loss: 1.1921 - acc: 0.6980
# 49/49 [==============================] - 20s 407ms/step - loss: 1.0667 - acc: 0.7344 - val_loss: 1.1921 - val_acc: 0.6980
# Epoch 22/100
# 10/10 [==============================] - 1s 127ms/step - loss: 1.2557 - acc: 0.6831
# 49/49 [==============================] - 20s 405ms/step - loss: 1.0452 - acc: 0.7428 - val_loss: 1.2557 - val_acc: 0.6831
# Epoch 23/100
# 10/10 [==============================] - 1s 125ms/step - loss: 1.1666 - acc: 0.6996
# 49/49 [==============================] - 20s 410ms/step - loss: 1.0274 - acc: 0.7460 - val_loss: 1.1666 - val_acc: 0.6996
# Epoch 24/100
# 10/10 [==============================] - 1s 134ms/step - loss: 1.2801 - acc: 0.6730
# 49/49 [==============================] - 20s 409ms/step - loss: 1.0111 - acc: 0.7524 - val_loss: 1.2801 - val_acc: 0.6730
# Epoch 25/100
# 10/10 [==============================] - 1s 136ms/step - loss: 1.1383 - acc: 0.7120
# 49/49 [==============================] - 20s 408ms/step - loss: 0.9939 - acc: 0.7574 - val_loss: 1.1383 - val_acc: 0.7120
# Epoch 26/100
# 10/10 [==============================] - 1s 132ms/step - loss: 1.1603 - acc: 0.7167
# 49/49 [==============================] - 20s 413ms/step - loss: 0.9659 - acc: 0.7654 - val_loss: 1.1603 - val_acc: 0.7167
# Epoch 27/100
# 10/10 [==============================] - 1s 132ms/step - loss: 1.0836 - acc: 0.7310
# 49/49 [==============================] - 20s 404ms/step - loss: 0.9560 - acc: 0.7710 - val_loss: 1.0836 - val_acc: 0.7310
# Epoch 28/100
# 10/10 [==============================] - 1s 133ms/step - loss: 1.1530 - acc: 0.7166
# 49/49 [==============================] - 20s 412ms/step - loss: 0.9386 - acc: 0.7753 - val_loss: 1.1530 - val_acc: 0.7166
# Epoch 29/100
# 10/10 [==============================] - 1s 129ms/step - loss: 1.1922 - acc: 0.7094
# 49/49 [==============================] - 20s 403ms/step - loss: 0.9239 - acc: 0.7826 - val_loss: 1.1922 - val_acc: 0.7094
# Epoch 30/100
# 10/10 [==============================] - 1s 125ms/step - loss: 1.3473 - acc: 0.6672
# 49/49 [==============================] - 20s 404ms/step - loss: 0.9113 - acc: 0.7829 - val_loss: 1.3473 - val_acc: 0.6672
# Epoch 31/100
# 10/10 [==============================] - 1s 132ms/step - loss: 1.0207 - acc: 0.7525
# 49/49 [==============================] - 20s 406ms/step - loss: 0.8905 - acc: 0.7913 - val_loss: 1.0207 - val_acc: 0.7525
# Epoch 32/100
# 10/10 [==============================] - 1s 135ms/step - loss: 1.1512 - acc: 0.7148
# 49/49 [==============================] - 20s 410ms/step - loss: 0.8854 - acc: 0.7916 - val_loss: 1.1512 - val_acc: 0.7148
# Epoch 33/100
# 10/10 [==============================] - 1s 133ms/step - loss: 0.9648 - acc: 0.7658
# 49/49 [==============================] - 20s 412ms/step - loss: 0.8753 - acc: 0.7945 - val_loss: 0.9648 - val_acc: 0.7658
# Epoch 34/100
# 10/10 [==============================] - 1s 134ms/step - loss: 1.2502 - acc: 0.7095
# 49/49 [==============================] - 20s 413ms/step - loss: 0.8590 - acc: 0.7986 - val_loss: 1.2502 - val_acc: 0.7095
# Epoch 35/100
# 10/10 [==============================] - 1s 129ms/step - loss: 1.2458 - acc: 0.6907
# 49/49 [==============================] - 20s 405ms/step - loss: 0.8419 - acc: 0.8026 - val_loss: 1.2458 - val_acc: 0.6907
# Epoch 36/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.9138 - acc: 0.7827
# 49/49 [==============================] - 20s 417ms/step - loss: 0.8349 - acc: 0.8048 - val_loss: 0.9138 - val_acc: 0.7827
# Epoch 37/100
# 10/10 [==============================] - 1s 129ms/step - loss: 1.0212 - acc: 0.7513
# 49/49 [==============================] - 20s 409ms/step - loss: 0.8277 - acc: 0.8065 - val_loss: 1.0212 - val_acc: 0.7513
# Epoch 38/100
# 10/10 [==============================] - 1s 129ms/step - loss: 1.0976 - acc: 0.7358
# 49/49 [==============================] - 20s 408ms/step - loss: 0.8173 - acc: 0.8093 - val_loss: 1.0976 - val_acc: 0.7358
# Epoch 39/100
# 10/10 [==============================] - 1s 138ms/step - loss: 1.0074 - acc: 0.7567
# 49/49 [==============================] - 20s 409ms/step - loss: 0.8058 - acc: 0.8141 - val_loss: 1.0074 - val_acc: 0.7567
# Epoch 40/100
# 10/10 [==============================] - 1s 134ms/step - loss: 1.0679 - acc: 0.7363
# 49/49 [==============================] - 20s 411ms/step - loss: 0.7910 - acc: 0.8180 - val_loss: 1.0679 - val_acc: 0.7363
# Epoch 41/100
# 10/10 [==============================] - 1s 133ms/step - loss: 0.8873 - acc: 0.7915
# 49/49 [==============================] - 20s 407ms/step - loss: 0.7808 - acc: 0.8215 - val_loss: 0.8873 - val_acc: 0.7915
# Epoch 42/100
# 10/10 [==============================] - 1s 141ms/step - loss: 1.0063 - acc: 0.7543
# 49/49 [==============================] - 20s 408ms/step - loss: 0.7766 - acc: 0.8212 - val_loss: 1.0063 - val_acc: 0.7543
# Epoch 43/100
# 10/10 [==============================] - 1s 129ms/step - loss: 1.0038 - acc: 0.7595
# 49/49 [==============================] - 20s 405ms/step - loss: 0.7689 - acc: 0.8232 - val_loss: 1.0038 - val_acc: 0.7595
# Epoch 44/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.9407 - acc: 0.7785
# 49/49 [==============================] - 20s 407ms/step - loss: 0.7552 - acc: 0.8289 - val_loss: 0.9407 - val_acc: 0.7785
# Epoch 45/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.9503 - acc: 0.7723
# 49/49 [==============================] - 20s 406ms/step - loss: 0.7461 - acc: 0.8315 - val_loss: 0.9503 - val_acc: 0.7723
# Epoch 46/100
# 10/10 [==============================] - 1s 133ms/step - loss: 0.8446 - acc: 0.8058
# 49/49 [==============================] - 20s 409ms/step - loss: 0.7398 - acc: 0.8315 - val_loss: 0.8446 - val_acc: 0.8058
# Epoch 47/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.8945 - acc: 0.7907
# 49/49 [==============================] - 20s 406ms/step - loss: 0.7404 - acc: 0.8314 - val_loss: 0.8945 - val_acc: 0.7907
# Epoch 48/100
# 10/10 [==============================] - 1s 122ms/step - loss: 0.9399 - acc: 0.7784
# 49/49 [==============================] - 20s 403ms/step - loss: 0.7235 - acc: 0.8376 - val_loss: 0.9399 - val_acc: 0.7784
# Epoch 49/100
# 10/10 [==============================] - 1s 126ms/step - loss: 1.0394 - acc: 0.7523
# 49/49 [==============================] - 20s 404ms/step - loss: 0.7103 - acc: 0.8408 - val_loss: 1.0394 - val_acc: 0.7523
# Epoch 50/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.9245 - acc: 0.7724
# 49/49 [==============================] - 20s 402ms/step - loss: 0.7075 - acc: 0.8399 - val_loss: 0.9245 - val_acc: 0.7724
# Epoch 51/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.8313 - acc: 0.8059
# 49/49 [==============================] - 20s 410ms/step - loss: 0.7105 - acc: 0.8402 - val_loss: 0.8313 - val_acc: 0.8059
# Epoch 52/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.7599 - acc: 0.8295
# 49/49 [==============================] - 20s 405ms/step - loss: 0.6551 - acc: 0.8598 - val_loss: 0.7599 - val_acc: 0.8295
# Epoch 53/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.7518 - acc: 0.8318
# 49/49 [==============================] - 20s 405ms/step - loss: 0.6464 - acc: 0.8619 - val_loss: 0.7518 - val_acc: 0.8318
# Epoch 54/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.7371 - acc: 0.8390
# 49/49 [==============================] - 20s 400ms/step - loss: 0.6431 - acc: 0.8637 - val_loss: 0.7371 - val_acc: 0.8390
# Epoch 55/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.7453 - acc: 0.8348
# 49/49 [==============================] - 20s 404ms/step - loss: 0.6406 - acc: 0.8653 - val_loss: 0.7453 - val_acc: 0.8348
# Epoch 56/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.7685 - acc: 0.8288
# 49/49 [==============================] - 20s 405ms/step - loss: 0.6370 - acc: 0.8663 - val_loss: 0.7685 - val_acc: 0.8288
# Epoch 57/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.7342 - acc: 0.8380
# 49/49 [==============================] - 20s 404ms/step - loss: 0.6348 - acc: 0.8647 - val_loss: 0.7342 - val_acc: 0.8380
# Epoch 58/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.7682 - acc: 0.8261
# 49/49 [==============================] - 20s 406ms/step - loss: 0.6333 - acc: 0.8638 - val_loss: 0.7682 - val_acc: 0.8261
# Epoch 59/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.7439 - acc: 0.8352
# 49/49 [==============================] - 20s 409ms/step - loss: 0.6325 - acc: 0.8653 - val_loss: 0.7439 - val_acc: 0.8352
# Epoch 60/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.7630 - acc: 0.8302
# 49/49 [==============================] - 20s 406ms/step - loss: 0.6290 - acc: 0.8681 - val_loss: 0.7630 - val_acc: 0.8302
# Epoch 61/100
# 10/10 [==============================] - 1s 133ms/step - loss: 0.7497 - acc: 0.8335
# 49/49 [==============================] - 20s 411ms/step - loss: 0.6251 - acc: 0.8702 - val_loss: 0.7497 - val_acc: 0.8335
# Epoch 62/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.7398 - acc: 0.8365
# 49/49 [==============================] - 20s 410ms/step - loss: 0.6283 - acc: 0.8676 - val_loss: 0.7398 - val_acc: 0.8365
# Epoch 63/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.7568 - acc: 0.8276
# 49/49 [==============================] - 20s 405ms/step - loss: 0.6238 - acc: 0.8689 - val_loss: 0.7568 - val_acc: 0.8276
# Epoch 64/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.7588 - acc: 0.8304
# 49/49 [==============================] - 20s 408ms/step - loss: 0.6249 - acc: 0.8691 - val_loss: 0.7588 - val_acc: 0.8304
# Epoch 65/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.7549 - acc: 0.8324
# 49/49 [==============================] - 20s 406ms/step - loss: 0.6238 - acc: 0.8686 - val_loss: 0.7549 - val_acc: 0.8324
# Epoch 66/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.7465 - acc: 0.8361
# 49/49 [==============================] - 20s 406ms/step - loss: 0.6223 - acc: 0.8698 - val_loss: 0.7465 - val_acc: 0.8361
# Epoch 67/100
# 10/10 [==============================] - 1s 148ms/step - loss: 0.7475 - acc: 0.8357
# 49/49 [==============================] - 20s 418ms/step - loss: 0.6199 - acc: 0.8705 - val_loss: 0.7475 - val_acc: 0.8357
# Epoch 68/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.7376 - acc: 0.8360
# 49/49 [==============================] - 20s 405ms/step - loss: 0.6196 - acc: 0.8719 - val_loss: 0.7376 - val_acc: 0.8360
# Epoch 69/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.7572 - acc: 0.8321
# 49/49 [==============================] - 20s 408ms/step - loss: 0.6154 - acc: 0.8714 - val_loss: 0.7572 - val_acc: 0.8321
# Epoch 70/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.7442 - acc: 0.8333
# 49/49 [==============================] - 20s 407ms/step - loss: 0.6173 - acc: 0.8699 - val_loss: 0.7442 - val_acc: 0.8333
# Epoch 71/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.7300 - acc: 0.8386
# 49/49 [==============================] - 20s 407ms/step - loss: 0.6161 - acc: 0.8720 - val_loss: 0.7300 - val_acc: 0.8386
# Epoch 72/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.7484 - acc: 0.8352
# 49/49 [==============================] - 20s 407ms/step - loss: 0.6166 - acc: 0.8699 - val_loss: 0.7484 - val_acc: 0.8352
# Epoch 73/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.7372 - acc: 0.8363
# 49/49 [==============================] - 20s 403ms/step - loss: 0.6151 - acc: 0.8714 - val_loss: 0.7372 - val_acc: 0.8363
# Epoch 74/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.7481 - acc: 0.8340
# 49/49 [==============================] - 20s 405ms/step - loss: 0.6123 - acc: 0.8731 - val_loss: 0.7481 - val_acc: 0.8340
# Epoch 75/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.7466 - acc: 0.8311
# 49/49 [==============================] - 20s 402ms/step - loss: 0.6108 - acc: 0.8731 - val_loss: 0.7466 - val_acc: 0.8311
# Epoch 76/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.7349 - acc: 0.8355
# 49/49 [==============================] - 20s 402ms/step - loss: 0.6089 - acc: 0.8738 - val_loss: 0.7349 - val_acc: 0.8355
# Epoch 77/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.7366 - acc: 0.8354
# 49/49 [==============================] - 20s 404ms/step - loss: 0.6061 - acc: 0.8741 - val_loss: 0.7366 - val_acc: 0.8354
# Epoch 78/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.7325 - acc: 0.8373
# 49/49 [==============================] - 20s 406ms/step - loss: 0.6075 - acc: 0.8732 - val_loss: 0.7325 - val_acc: 0.8373
# Epoch 79/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.7387 - acc: 0.8356
# 49/49 [==============================] - 20s 408ms/step - loss: 0.6051 - acc: 0.8742 - val_loss: 0.7387 - val_acc: 0.8356
# Epoch 80/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.7358 - acc: 0.8369
# 49/49 [==============================] - 20s 405ms/step - loss: 0.6035 - acc: 0.8743 - val_loss: 0.7358 - val_acc: 0.8369
# Epoch 81/100
# 10/10 [==============================] - 1s 133ms/step - loss: 0.7356 - acc: 0.8369
# 49/49 [==============================] - 20s 406ms/step - loss: 0.6029 - acc: 0.8754 - val_loss: 0.7356 - val_acc: 0.8369
# Epoch 82/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.7388 - acc: 0.8369
# 49/49 [==============================] - 20s 402ms/step - loss: 0.6050 - acc: 0.8749 - val_loss: 0.7388 - val_acc: 0.8369
# Epoch 83/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.7358 - acc: 0.8361
# 49/49 [==============================] - 20s 406ms/step - loss: 0.6021 - acc: 0.8746 - val_loss: 0.7358 - val_acc: 0.8361
# Epoch 84/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.7367 - acc: 0.8370
# 49/49 [==============================] - 20s 401ms/step - loss: 0.6013 - acc: 0.8755 - val_loss: 0.7367 - val_acc: 0.8370
# Epoch 85/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.7377 - acc: 0.8375
# 49/49 [==============================] - 20s 405ms/step - loss: 0.6063 - acc: 0.8728 - val_loss: 0.7377 - val_acc: 0.8375
# Epoch 86/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.7350 - acc: 0.8371
# 49/49 [==============================] - 20s 403ms/step - loss: 0.6044 - acc: 0.8753 - val_loss: 0.7350 - val_acc: 0.8371
# Epoch 87/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.7364 - acc: 0.8375
# 49/49 [==============================] - 20s 403ms/step - loss: 0.6052 - acc: 0.8732 - val_loss: 0.7364 - val_acc: 0.8375
# Epoch 88/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.7332 - acc: 0.8370
# 49/49 [==============================] - 20s 405ms/step - loss: 0.6029 - acc: 0.8739 - val_loss: 0.7332 - val_acc: 0.8370
# Epoch 89/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.7347 - acc: 0.8383
# 49/49 [==============================] - 20s 406ms/step - loss: 0.6002 - acc: 0.8758 - val_loss: 0.7347 - val_acc: 0.8383
# Epoch 90/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.7350 - acc: 0.8374
# 49/49 [==============================] - 20s 402ms/step - loss: 0.6037 - acc: 0.8753 - val_loss: 0.7350 - val_acc: 0.8374
# Epoch 91/100
# 10/10 [==============================] - 1s 134ms/step - loss: 0.7340 - acc: 0.8369
# 49/49 [==============================] - 20s 404ms/step - loss: 0.6033 - acc: 0.8757 - val_loss: 0.7340 - val_acc: 0.8369
# Epoch 92/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.7359 - acc: 0.8379
# 49/49 [==============================] - 20s 402ms/step - loss: 0.6016 - acc: 0.8774 - val_loss: 0.7359 - val_acc: 0.8379
# Epoch 93/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.7345 - acc: 0.8378
# 49/49 [==============================] - 20s 401ms/step - loss: 0.6038 - acc: 0.8756 - val_loss: 0.7345 - val_acc: 0.8378
# Epoch 94/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.7411 - acc: 0.8351
# 49/49 [==============================] - 20s 404ms/step - loss: 0.6018 - acc: 0.8764 - val_loss: 0.7411 - val_acc: 0.8351
# Epoch 95/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.7336 - acc: 0.8387
# 49/49 [==============================] - 20s 406ms/step - loss: 0.6023 - acc: 0.8756 - val_loss: 0.7336 - val_acc: 0.8387
# Epoch 96/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.7333 - acc: 0.8376
# 49/49 [==============================] - 20s 408ms/step - loss: 0.6020 - acc: 0.8759 - val_loss: 0.7333 - val_acc: 0.8376
# Epoch 97/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.7317 - acc: 0.8376
# 49/49 [==============================] - 20s 409ms/step - loss: 0.6033 - acc: 0.8734 - val_loss: 0.7317 - val_acc: 0.8376
# Epoch 98/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.7357 - acc: 0.8377
# 49/49 [==============================] - 20s 412ms/step - loss: 0.6026 - acc: 0.8768 - val_loss: 0.7357 - val_acc: 0.8377
# Epoch 99/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.7318 - acc: 0.8374
# 49/49 [==============================] - 20s 413ms/step - loss: 0.6005 - acc: 0.8768 - val_loss: 0.7318 - val_acc: 0.8374
# Epoch 100/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.7328 - acc: 0.8369
# 49/49 [==============================] - 20s 405ms/step - loss: 0.6018 - acc: 0.8765 - val_loss: 0.7328 - val_acc: 0.8369
